# %%
# %pip install openpyxl

# %%
import pandas as pd
import openpyxl

# %%
df_kl = pd.read_excel('pathokl.xlsx')
df_aiq = pd.read_excel('aiq.xlsx')

df_kl.columns.tolist()

# %%
df_aiq.columns.tolist()

# %%
merged_side = pd.merge(df_aiq, df_kl, how='inner', on='Rank')
merged_side

# %%
merged_side.to_excel('patho merged.xlsx')
